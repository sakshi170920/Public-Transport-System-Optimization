# %%
#Import files module
import pandas as pd
import csv
import re                     ##Regular expressions
import glob
import os
import logging
import numpy as np
import datetime
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from math import sqrt
from numpy import concatenate
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from matplotlib import pyplot as plt
import tensorflow as tf

import warnings
warnings.filterwarnings('ignore')

# %%
#logging mechanism for debugging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
#Mapping months to numeric values
months = {'01':'Jan','02':'Feb','03':'Mar','04':'Apr','05':'May','06':'June','07':'July','08':'Aug','09':'Sept','10':'Oct','11':'Nov','12':'Dec'}

# %%
import pandas as pd

#Importing files from specific folders and list of holidays
bus_no='6080'                                                 #Route number - Change this value accordingly 
path = r'C:\Users\Admin\Documents\Public-Transport-System-Optimization\Dynamic Timetable Generation\data\\'+bus_no+'/Up'     #Up Direction files folder Path - Change the path accordingly    
down_path = r'C:\Users\Admin\Documents\Public-Transport-System-Optimization\Dynamic Timetable Generation\data\\'+bus_no+'/Down'    #Down Direction files folder path - Change the path accordingly
allfiles = glob.glob(path + "/*.csv")
down_allfiles = glob.glob(down_path + "/*.csv")
Holiday_colnames = ['Holiday', 'Date', 'Day', 'Month']
Holiday_data = pd.read_csv(r'C:\Users\Admin\Documents\Public-Transport-System-Optimization\Dynamic Timetable Generation\List of Holidays.csv', names=Holiday_colnames)     #Holiday list for 2018
#Holiday_2017 = pd.read_csv('D:\Dharmit\Final Year Project\List of holidays 2017.csv', names=Holiday_colnames)      #Holiday list for 2017
feature_names =  ['Time Slot','Trips','Passengers','Day','isHoliday']

# %%
print(allfiles[:3])
# Out:
# ['C:\\Users\\Admin\\Documents\\Public-Transport-System-Optimization\\Dynamic Timetable Generation\\data\\\\6080/Up\\Clean data6080_Up_01_Feb_Thursday.csv', 'C:\\Users\\Admin\\Documents\\Public-Transport-System-Optimization\\Dynamic Timetable Generation\\data\\\\6080/Up\\Clean data6080_Up_01_Jan_Monday.csv', 'C:\\Users\\Admin\\Documents\\Public-Transport-System-Optimization\\Dynamic Timetable Generation\\data\\\\6080/Up\\Clean data6080_Up_02_Feb_Friday.csv']

# %% [markdown]
# # Up direction processing

# %%
#Making separate dataframes for each separate timeslot over many days
df1=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df2=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df3=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df4=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df5=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df6=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df7=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df8=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df9=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df10=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df11=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df12=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df13=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df14=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df15=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df16=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df17=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df18=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df19=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df20=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df=[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20]

#Dicing only requird data from list of holidays
holiday_day = Holiday_data['Day']
holiday_month = Holiday_data['Month']

# %%
Timeslot_values= ['00:00:01-05:00:00','05:00:01-06:00:00','06:00:01-07:00:00','07:00:01-08:00:00','08:00:01-09:00:00','09:00:01-10:00:00','10:00:01-11:00:00','11:00:01-12:00:00','12:00:01-13:00:00','13:00:01-14:00:00','14:00:01-15:00:00','15:00:01-16:00:00','16:00:01-17:00:00','17:00:01-18:00:00','18:00:01-19:00:00','19:00:01-20:00:00','20:00:01-21:00:00','21:00:01-22:00:00','22:00:01-23:00:00','23:00:01-24:00:00']
Days = {'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6,'Sunday':7}

#Obtaining the day and date details for current day 
now = datetime.datetime.now()   
current_month = months[str(now.month).zfill(2)] 
current_day = now.day
isCurrDay_holiday = 0
current_dow = Days[now.strftime("%A")]           #Obtaining current day of the week
for i in range(1,23):                            #checking if there is holiday today
    if(holiday_day[i]==current_day and current_month==holiday_month[i]):
        isCurrDay_holiday=1

for files in allfiles:
    #Obtaining Day and date details from filename
    base = os.path.basename(files)
    day = os.path.splitext(base)[0][25:]
    date = os.path.splitext(base)[0][18:20]

    month = os.path.splitext(base)[0][21:24]
    #year = os.path.splitext(base)[0][18:22]
    #Determining whether holiday or not
    holiday = 0
    for i in range(1,23):
        if(holiday_day[i]==date and months[month]==holiday_month[i]):
            holiday=1
            
    #Pre-processing data into required format
    day = Days[day]                                        #Mapping day to numeric value
    with open(files,'r') as f:
        timeslot = []
        trips = []
        passengers = []
        reader = csv.reader(f, delimiter=",")
        rows = [r for r in reader]
        for x in rows[1:]:
            timeslot.append(x[1])
            trips.append(x[2])
            if(x[3]==''):
                x[3]=0
            passengers.append(x[3])
 
    #Adding data into the dataframes created previously according to time slots
    for j in range(len(timeslot)):
        df[j]= df[j].append(pd.Series([timeslot[j],trips[j],int(passengers[j]),day,holiday], index = ['Time Slot','Trips','Passengers','Day','isHoliday']), ignore_index=True)
        df[j]=df[j].replace('',0)                      #Replacing NAN values by 0

# %%
df[5].head()
# Out:
#            Time Slot Trips Passengers Day isHoliday
# 0  09:00:01-10:00:00     4         13   4         0
# 1  09:00:01-10:00:00     2          7   1         0
# 2  09:00:01-10:00:00     2         25   5         0
# 3  09:00:01-10:00:00     4         13   2         0
# 4  09:00:01-10:00:00     3         16   6         0

# %%
x,y = [],[]
for i in range(len(df)):
    x.extend(df[i]['Passengers'][df[i]['Day']==7])
    y.extend(df[i]['Passengers'][df[i]['Day']==2])
plt.rcParams["figure.figsize"] = (15,6)
plt.plot(x,color='green',label='Sunday')
plt.plot(y,color='black',label='Tuesday')
plt.title("Passengers Travel Data")
plt.xlabel("Time")
plt.ylabel("Passenger Count")
plt.legend()
plt.show()

#One can see the clear difference of passengers on a Sunday and on a Tuesday.
#Hence accounting these changes to predict trips and schedule timetable is important.

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg


rmse_total = 0
nor_rmse_total = 0
rmse_total_train = 0
forecasted_trips = []
min_trips = -1
max_trips = -1
lags = 1
# load dataset
for i in range(0,20):
    dataset = df[i].copy()
    dataset.drop('Time Slot',axis=1,inplace=True)
    values = dataset.values
    # ensure all data is float
    values = values.astype('float32')
    # normalize features
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(values)
    # frame as supervised learning
    reframed = series_to_supervised(scaled, lags, 1)
    #print(reframed)
    # drop columns we don't want to predict i.e passenger, day, isHoliday 
    reframed.drop(reframed.columns[-3:], axis=1, inplace=True)
    print(reframed.head()) #To debug
#     print(reframed.columns[-3:])
    min_trips = max(reframed["var1(t)"])
    max_trips = min(reframed["var1(t)"])
    #print(min_trips,max_trips)


    
    #Divide Data into Training and test set
    values = reframed.values
    n_train_steps = int(len(values) * 0.7)                #Training set size
    train_set = values[:n_train_steps, :]
    test_set = values[n_train_steps:, :]
#     print('Observations: %d' % (len(values)))
#     print('Training Observations: %d' % (len(train_set)))
#     print('Testing Observations: %d' % (len(test_set)))
    # split into input and outputs
    train_X, train_y = train_set[:-1,:-1], train_set[:-1,-1]
    test_X, test_y = test_set[-1:,:-1], test_set[-1:,-1]
    
    # reshape input to be 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
    test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
    
    # design network
    model = Sequential()
    model.add(LSTM(5, activation='relu', return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))    #Adding LSTM units into the RNN
    #model.add(LSTM(7, activation='relu', return_sequences=True))
    model.add(LSTM(3, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mae', optimizer='adam')                             #mae-Mean Absolute error, Adam optimization rule
    # fit network
    history = model.fit(train_X, train_y, epochs=20, batch_size=3, verbose=1, shuffle=False)
  

#     plt.plot(history.history['loss'])
#     plt.plot(history.history['val_loss'])
#     plt.title('model train vs validation loss')
#     plt.ylabel('loss')
#     plt.xlabel('epoch')
#     plt.legend(['train', 'validation'], loc='upper right')
#     plt.show()
#     plt.plot(history.history['accuracy'])
#     plt.plot(history.history['val_accuracy'])
#     plt.title('model train vs validation accuracy')
#     plt.ylabel('accouracy')
#     plt.xlabel('epoch')
#     plt.legend(['train', 'validation'], loc='upper right')
#     plt.show()

    #obtaining predictions
    test_prediction = model.predict(test_X)
    train_prediction = model.predict(train_X)
    test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
    train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))

    # invert scaling for forecast
    print(test_prediction)
    actual_prediction = concatenate((test_prediction, test_X[:, 1:]), axis=1)
    actual_prediction = scaler.inverse_transform(actual_prediction)
    actual_prediction = actual_prediction[:,0]
    for x in actual_prediction:
        print(round(x))
        if round(x)<=0:
            forecasted_trips.append(0)
        else:
            forecasted_trips.append(round(x))
    actual_train_prediction = concatenate((train_prediction, train_X[:, 1:]), axis=1)
    actual_train_prediction = scaler.inverse_transform(actual_train_prediction)
    actual_train_prediction = actual_train_prediction[:,0]
    
    #invert scaling for actual ie. already available predictions(teacher signal)
    test_y = test_y.reshape((len(test_y), 1))
    inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
    inv_y = scaler.inverse_transform(inv_y)
    inv_y = inv_y[:,0]
    print(inv_y)
    #print df[i]['Trips']
    
     #invert scaling for actual ie. already available predictions(teacher signal) for training set
    train_y = train_y.reshape((len(train_y),1))
    inv_y_train = concatenate((train_y, train_X[:, 1:]), axis=1)
    inv_y_train = scaler.inverse_transform(inv_y_train)
    inv_y_train = inv_y_train[:,0]
    
    
    # calculate RMSE
    rmse = sqrt(mean_squared_error(inv_y,actual_prediction))
    #normalized rmse
    #nor_rmse = rmse/(max_trips - min_trips)
    rmse_total += float(rmse)
    #nor_rmse_total += float(nor_rmse)
    
    print("For df ",i,":", ('Test RMSE: %.3f' % rmse))
    #print((' Test Normalised RMSE: %.3f' % nor_rmse))
    
    
    rmse_train = sqrt(mean_squared_error(inv_y_train, actual_train_prediction))
    rmse_total_train += float(rmse_train)
    #print "For df ",i,":", ('Train RMSE: %.3f' % rmse_train)
print(rmse_total/20.0) #, rmse_total_train/20.0
print(nor_rmse_total)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var1(t)
# 1        0.0        0.0   0.500000        0.0      0.0
# 2        0.0        0.0   0.000000        0.0      0.0
# 3        0.0        0.0   0.666667        0.0      0.0
# 4        0.0        0.0   0.166667        0.0      0.0
# 5        0.0        0.0   0.833333        0.0      0.0
# Epoch 1/20
# 10/10 [==============================] - 3s 3ms/step - loss: 0.1088
# Epoch 2/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1078
# Epoch 3/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1076
# Epoch 4/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1070
# Epoch 5/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1066
# Epoch 6/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1066
# Epoch 7/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1064
# Epoch 8/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1064
# Epoch 9/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1064
# Epoch 10/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1065
# Epoch 11/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1065
# Epoch 12/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1064
# Epoch 13/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1064
# Epoch 14/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1064
# Epoch 15/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1065
# Epoch 16/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1064
# Epoch 17/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1064
# Epoch 18/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1063
# Epoch 19/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1064
# Epoch 20/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1064
# [[0.00082125]]
# 0
# [0.]
# For df  0 : Test RMSE: 0.011
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var1(t)
# 1        0.0        0.0   0.500000        0.0      0.0
# 2        0.0        0.0   0.000000        0.0      0.0
# 3        0.0        0.0   0.666667        0.0      0.0
# 4        0.0        0.0   0.166667        0.0      0.0
# 5        0.0        0.0   0.833333        0.0      0.0
# Epoch 1/20
# 10/10 [==============================] - 2s 3ms/step - loss: 0.0963
# Epoch 2/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0973
# Epoch 3/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0965
# Epoch 4/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0964
# Epoch 5/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0961
# Epoch 6/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0966
# Epoch 7/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0963
# Epoch 8/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0963
# Epoch 9/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0963
# Epoch 10/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0961
# Epoch 11/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0966
# Epoch 12/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0963
# Epoch 13/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0963
# Epoch 14/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0963
# Epoch 15/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0961
# Epoch 16/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0966
# Epoch 17/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0963
# Epoch 18/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0963
# Epoch 19/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0963
# Epoch 20/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0961
# [[0.00074733]]
# 0
# [0.]
# For df  1 : Test RMSE: 0.010
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var1(t)
# 1      0.375   0.068027   0.500000        0.0    0.625
# 2      0.625   0.115646   0.000000        0.0    0.500
# 3      0.500   0.040816   0.666667        0.0    0.375
# 4      0.375   0.095238   0.166667        0.0    0.250
# 5      0.250   0.047619   0.833333        0.0    0.375
# Epoch 1/20
# 10/10 [==============================] - 3s 3ms/step - loss: 0.3189
# Epoch 2/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3098
# Epoch 3/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3006
# Epoch 4/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2910
# Epoch 5/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2810
# Epoch 6/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2707
# Epoch 7/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2599
# Epoch 8/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2487
# Epoch 9/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2390
# Epoch 10/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2317
# Epoch 11/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2254
# Epoch 12/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2192
# Epoch 13/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2129
# Epoch 14/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2064
# Epoch 15/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1997
# Epoch 16/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1926
# Epoch 17/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1885
# Epoch 18/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1866
# Epoch 19/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1862
# Epoch 20/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1860
# [[0.28034157]]
# 4
# [5.]
# For df  2 : Test RMSE: 0.757
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1   0.444444   0.207101   0.500000        0.0  0.333333
# 2   0.333333   0.071006   0.000000        0.0  0.444444
# 3   0.444444   0.213018   0.666667        0.0  0.444444
# 4   0.444444   0.147929   0.166667        0.0  0.555556
# 5   0.555556   0.130178   0.833333        0.0  0.444444
# Epoch 1/20
# 10/10 [==============================] - 3s 3ms/step - loss: 0.4536
# Epoch 2/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4417
# Epoch 3/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4286
# Epoch 4/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4150
# Epoch 5/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4009
# Epoch 6/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3862
# Epoch 7/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3708
# Epoch 8/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3545
# Epoch 9/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3385
# Epoch 10/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3220
# Epoch 11/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3046
# Epoch 12/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2883
# Epoch 13/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2708
# Epoch 14/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2549
# Epoch 15/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2397
# Epoch 16/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2263
# Epoch 17/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2125
# Epoch 18/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2031
# Epoch 19/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1942
# Epoch 20/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1889
# [[0.37644342]]
# 5
# [6.]
# For df  3 : Test RMSE: 0.612
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1   0.222222   0.035714   0.500000        0.0  0.444444
# 2   0.444444   0.061905   0.000000        0.0  0.444444
# 3   0.444444   0.004762   0.666667        0.0  0.333333
# 4   0.333333   0.038095   0.166667        0.0  0.333333
# 5   0.333333   0.035714   0.833333        0.0  0.222222
# Epoch 1/20
# 10/10 [==============================] - 3s 3ms/step - loss: 0.2650
# Epoch 2/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2556
# Epoch 3/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2470
# Epoch 4/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2383
# Epoch 5/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2295
# Epoch 6/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2204
# Epoch 7/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2110
# Epoch 8/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2017
# Epoch 9/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1941
# Epoch 10/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1887
# Epoch 11/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1846
# Epoch 12/20
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1806
# Epoch 13/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1768
# Epoch 14/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1729
# Epoch 15/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1689
# Epoch 16/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1649
# Epoch 17/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1607
# Epoch 18/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1564
# Epoch 19/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1523
# Epoch 20/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1501
# [[0.1950669]]
# 4
# [5.]
# For df  4 : Test RMSE: 1.244
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1   0.200000   0.013559   0.500000        0.0  0.066667
# 2   0.066667   0.003390   0.000000        0.0  0.066667
# 3   0.066667   0.033898   0.666667        0.0  0.200000
# 4   0.200000   0.013559   0.166667        0.0  0.133333
# 5   0.133333   0.018644   0.833333        0.0  0.000000
# Epoch 1/20
# 10/10 [==============================] - 2s 3ms/step - loss: 0.2221
# Epoch 2/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2136
# Epoch 3/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2052
# Epoch 4/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1968
# Epoch 5/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1885
# Epoch 6/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1802
# Epoch 7/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1719
# Epoch 8/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1648
# Epoch 9/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1604
# Epoch 10/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1562
# Epoch 11/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1520
# Epoch 12/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1478
# Epoch 13/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1436
# Epoch 14/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1394
# Epoch 15/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1351
# Epoch 16/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1308
# Epoch 17/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1286
# Epoch 18/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1291
# Epoch 19/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1292
# Epoch 20/20
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1292
# [[0.13564812]]
# 3
# [4.]
# For df  5 : Test RMSE: 0.965
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1   0.333333      0.425   0.500000        0.0  0.666667
# 2   0.666667      0.525   0.000000        0.0  1.000000
# 3   1.000000      0.900   0.666667        0.0  1.000000
# 4   1.000000      0.650   0.166667        0.0  1.000000
# 5   1.000000      0.425   0.833333        0.0  0.000000
# Epoch 1/20
# 9/9 [==============================] - 2s 4ms/step - loss: 0.6298
# Epoch 2/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6170
# Epoch 3/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6038
# Epoch 4/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5904
# Epoch 5/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5767
# Epoch 6/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5626
# Epoch 7/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5479
# Epoch 8/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5327
# Epoch 9/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5166
# Epoch 10/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4994
# Epoch 11/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4816
# Epoch 12/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4642
# Epoch 13/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4461
# Epoch 14/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4267
# Epoch 15/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4057
# Epoch 16/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3825
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3593
# Epoch 18/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3362
# Epoch 19/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3142
# Epoch 20/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2904
# [[0.4941503]]
# 3
# [5.]
# For df  6 : Test RMSE: 2.035
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var1(t)
# 1        0.4   0.285714   0.500000        0.0      1.0
# 2        1.0   1.000000   0.000000        0.0      0.4
# 3        0.4   0.510204   0.666667        0.0      0.6
# 4        0.6   0.285714   0.166667        0.0      0.6
# 5        0.6   0.877551   0.833333        0.0      0.0
# Epoch 1/20
# 9/9 [==============================] - 3s 3ms/step - loss: 0.6128
# Epoch 2/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6039
# Epoch 3/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5956
# Epoch 4/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5874
# Epoch 5/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5793
# Epoch 6/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5712
# Epoch 7/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5630
# Epoch 8/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5549
# Epoch 9/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5468
# Epoch 10/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5387
# Epoch 11/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5305
# Epoch 12/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5224
# Epoch 13/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5143
# Epoch 14/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5062
# Epoch 15/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4981
# Epoch 16/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4900
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4819
# Epoch 18/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4738
# Epoch 19/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4656
# Epoch 20/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4575
# [[0.17582826]]
# 1
# [3.]
# For df  7 : Test RMSE: 2.121
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1   0.571429   0.542373   0.500000        0.0  0.285714
# 2   0.285714   0.610169   0.000000        0.0  0.428571
# 3   0.428571   0.932203   0.666667        0.0  0.428571
# 4   0.428571   1.000000   0.166667        0.0  0.428571
# 5   0.428571   0.762712   0.833333        0.0  0.000000
# Epoch 1/20
# 9/9 [==============================] - 3s 3ms/step - loss: 0.3865
# Epoch 2/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3781
# Epoch 3/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3696
# Epoch 4/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3611
# Epoch 5/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3524
# Epoch 6/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3436
# Epoch 7/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3347
# Epoch 8/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3257
# Epoch 9/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3166
# Epoch 10/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3072
# Epoch 11/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2977
# Epoch 12/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2880
# Epoch 13/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2780
# Epoch 14/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2677
# Epoch 15/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2576
# Epoch 16/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2480
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2385
# Epoch 18/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2287
# Epoch 19/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2186
# Epoch 20/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2080
# [[0.2075979]]
# 1
# [2.]
# For df  8 : Test RMSE: 0.547
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1   0.666667   0.588235   0.500000        0.0  0.666667
# 2   0.666667   0.862745   0.000000        0.0  0.333333
# 3   0.333333   0.372549   0.666667        0.0  0.666667
# 4   0.666667   1.000000   0.166667        0.0  0.666667
# 5   0.666667   0.490196   0.833333        0.0  0.000000
# Epoch 1/20
# 9/9 [==============================] - 3s 3ms/step - loss: 0.4473
# Epoch 2/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4420
# Epoch 3/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4373
# Epoch 4/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4326
# Epoch 5/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4280
# Epoch 6/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4233
# Epoch 7/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4187
# Epoch 8/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4140
# Epoch 9/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4093
# Epoch 10/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4047
# Epoch 11/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4000
# Epoch 12/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3954
# Epoch 13/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3907
# Epoch 14/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3860
# Epoch 15/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3814
# Epoch 16/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3767
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3720
# Epoch 18/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3674
# Epoch 19/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3627
# Epoch 20/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3580
# [[0.15195154]]
# 1
# [1.]
# For df  9 : Test RMSE: 0.456
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var1(t)
# 1        1.0   0.428571   0.500000        0.0      0.8
# 2        0.8   0.681319   0.000000        0.0      0.6
# 3        0.6   0.428571   0.666667        0.0      0.8
# 4        0.8   1.000000   0.166667        0.0      0.8
# 5        0.8   0.593407   0.833333        0.0      0.0
# Epoch 1/20
# 9/9 [==============================] - 2s 3ms/step - loss: 0.6821
# Epoch 2/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6705
# Epoch 3/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6584
# Epoch 4/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6456
# Epoch 5/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6318
# Epoch 6/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6169
# Epoch 7/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6007
# Epoch 8/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5830
# Epoch 9/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5640
# Epoch 10/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5436
# Epoch 11/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5213
# Epoch 12/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4965
# Epoch 13/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4687
# Epoch 14/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4373
# Epoch 15/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4017
# Epoch 16/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3613
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3198
# Epoch 18/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2800
# Epoch 19/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2378
# Epoch 20/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2095
# [[0.47261593]]
# 2
# [4.]
# For df  10 : Test RMSE: 1.637
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1   0.285714   0.436170   0.500000        0.0  0.571429
# 2   0.571429   0.776596   0.000000        0.0  0.571429
# 3   0.571429   0.414894   0.666667        0.0  0.428571
# 4   0.428571   0.872340   0.166667        0.0  0.285714
# 5   0.285714   0.361702   0.833333        0.0  0.000000
# Epoch 1/20
# 9/9 [==============================] - 2s 3ms/step - loss: 0.5238
# Epoch 2/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5155
# Epoch 3/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5071
# Epoch 4/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4986
# Epoch 5/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4900
# Epoch 6/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4812
# Epoch 7/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4723
# Epoch 8/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4631
# Epoch 9/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4537
# Epoch 10/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4439
# Epoch 11/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4337
# Epoch 12/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4228
# Epoch 13/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4113
# Epoch 14/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3987
# Epoch 15/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3849
# Epoch 16/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3694
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3519
# Epoch 18/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3318
# Epoch 19/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3085
# Epoch 20/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2811
# [[0.30540207]]
# 2
# [3.]
# For df  11 : Test RMSE: 0.862
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var1(t)
# 1        0.8   0.603448   0.500000        0.0      0.6
# 2        0.6   0.379310   0.000000        0.0      0.6
# 3        0.6   0.508621   0.666667        0.0      0.6
# 4        0.6   0.500000   0.166667        0.0      0.4
# 5        0.4   0.258621   0.833333        0.0      0.0
# Epoch 1/20
# 9/9 [==============================] - 2s 3ms/step - loss: 0.5452
# Epoch 2/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5348
# Epoch 3/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5262
# Epoch 4/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5182
# Epoch 5/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5101
# Epoch 6/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5021
# Epoch 7/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4940
# Epoch 8/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4859
# Epoch 9/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4778
# Epoch 10/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4698
# Epoch 11/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4617
# Epoch 12/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4536
# Epoch 13/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4455
# Epoch 14/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4374
# Epoch 15/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4294
# Epoch 16/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4213
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4132
# Epoch 18/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4051
# Epoch 19/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3970
# Epoch 20/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3889
# [[0.175143]]
# 1
# [4.]
# For df  12 : Test RMSE: 3.124
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1   0.500000   0.357143   0.500000        0.0  0.500000
# 2   0.500000   0.550000   0.000000        0.0  0.666667
# 3   0.666667   0.492857   0.666667        0.0  1.000000
# 4   1.000000   1.000000   0.166667        0.0  0.500000
# 5   0.500000   0.392857   0.833333        0.0  0.000000
# Epoch 1/20
# 9/9 [==============================] - 2s 5ms/step - loss: 0.4966
# Epoch 2/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4884
# Epoch 3/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4802
# Epoch 4/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4720
# Epoch 5/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4637
# Epoch 6/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4553
# Epoch 7/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4468
# Epoch 8/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4381
# Epoch 9/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4292
# Epoch 10/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4201
# Epoch 11/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4108
# Epoch 12/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4011
# Epoch 13/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3911
# Epoch 14/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3807
# Epoch 15/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3699
# Epoch 16/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3586
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3473
# Epoch 18/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3372
# Epoch 19/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3274
# Epoch 20/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3173
# [[0.21220279]]
# 1
# [4.]
# For df  13 : Test RMSE: 2.727
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1   0.333333   0.428571   0.500000        0.0  0.833333
# 2   0.833333   0.709821   0.000000        0.0  0.833333
# 3   0.833333   0.500000   0.666667        0.0  0.833333
# 4   0.833333   1.000000   0.166667        0.0  0.500000
# 5   0.500000   0.165179   0.833333        0.0  0.000000
# Epoch 1/20
# 9/9 [==============================] - 2s 3ms/step - loss: 0.5043
# Epoch 2/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4943
# Epoch 3/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4848
# Epoch 4/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4752
# Epoch 5/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4656
# Epoch 6/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4558
# Epoch 7/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4458
# Epoch 8/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4355
# Epoch 9/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4250
# Epoch 10/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4141
# Epoch 11/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4028
# Epoch 12/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3910
# Epoch 13/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3784
# Epoch 14/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3651
# Epoch 15/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3512
# Epoch 16/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3392
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3265
# Epoch 18/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3127
# Epoch 19/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2974
# Epoch 20/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2803
# [[0.2783572]]
# 2
# [4.]
# For df  14 : Test RMSE: 2.330
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1   0.500000   0.505791   0.500000        0.0  0.833333
# 2   0.833333   0.768340   0.000000        0.0  0.666667
# 3   0.666667   0.706564   0.666667        0.0  0.500000
# 4   0.500000   0.633205   0.166667        0.0  0.666667
# 5   0.666667   0.366795   0.833333        0.0  0.000000
# Epoch 1/20
# 9/9 [==============================] - 2s 3ms/step - loss: 0.5522
# Epoch 2/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5414
# Epoch 3/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5304
# Epoch 4/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5191
# Epoch 5/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5075
# Epoch 6/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4956
# Epoch 7/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4833
# Epoch 8/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4706
# Epoch 9/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4574
# Epoch 10/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4435
# Epoch 11/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4290
# Epoch 12/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4137
# Epoch 13/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3975
# Epoch 14/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3802
# Epoch 15/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3613
# Epoch 16/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3406
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3177
# Epoch 18/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2922
# Epoch 19/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2646
# Epoch 20/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2401
# [[0.3460716]]
# 2
# [4.]
# For df  15 : Test RMSE: 1.924
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)
# 1   0.833333   1.000000   0.500000        0.0  0.500000
# 2   0.500000   0.352941   0.000000        0.0  0.500000
# 3   0.500000   0.617647   0.666667        0.0  0.833333
# 4   0.833333   0.680147   0.166667        0.0  0.333333
# 5   0.333333   0.378676   0.833333        0.0  0.000000
# Epoch 1/20
# 9/9 [==============================] - 3s 3ms/step - loss: 0.5302
# Epoch 2/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5192
# Epoch 3/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5080
# Epoch 4/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4965
# Epoch 5/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4846
# Epoch 6/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4723
# Epoch 7/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4595
# Epoch 8/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4460
# Epoch 9/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4317
# Epoch 10/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4164
# Epoch 11/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4016
# Epoch 12/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3864
# Epoch 13/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3703
# Epoch 14/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3530
# Epoch 15/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3342
# Epoch 16/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3137
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2914
# Epoch 18/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2741
# Epoch 19/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2594
# Epoch 20/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2443
# [[0.42176753]]
# 3
# [5.]
# For df  16 : Test RMSE: 2.469
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var1(t)
# 1        1.0   0.453390   0.500000        0.0      0.8
# 2        0.8   0.584746   0.000000        0.0      0.6
# 3        0.6   0.622881   0.666667        0.0      0.8
# 4        0.8   0.868644   0.166667        0.0      0.4
# 5        0.4   0.279661   0.833333        0.0      0.0
# Epoch 1/20
# 9/9 [==============================] - 2s 3ms/step - loss: 0.6105
# Epoch 2/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6013
# Epoch 3/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5919
# Epoch 4/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5823
# Epoch 5/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5726
# Epoch 6/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5627
# Epoch 7/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5526
# Epoch 8/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5422
# Epoch 9/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5314
# Epoch 10/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5202
# Epoch 11/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5085
# Epoch 12/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4962
# Epoch 13/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4833
# Epoch 14/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4696
# Epoch 15/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4550
# Epoch 16/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4393
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4237
# Epoch 18/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4076
# Epoch 19/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3902
# Epoch 20/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3712
# [[0.2768778]]
# 1
# [2.]
# For df  17 : Test RMSE: 0.616
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var1(t)
# 1        0.4   0.585635   0.500000        0.0      0.8
# 2        0.8   0.569061   0.000000        0.0      1.0
# 3        1.0   0.453039   0.666667        0.0      0.6
# 4        0.6   0.508287   0.166667        0.0      0.6
# 5        0.6   0.464088   0.833333        0.0      0.0
# Epoch 1/20
# 9/9 [==============================] - 2s 2ms/step - loss: 0.6732
# Epoch 2/20
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6648
# Epoch 3/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6550
# Epoch 4/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6441
# Epoch 5/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6329
# Epoch 6/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6214
# Epoch 7/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6096
# Epoch 8/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5975
# Epoch 9/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5849
# Epoch 10/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5718
# Epoch 11/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5579
# Epoch 12/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5431
# Epoch 13/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5272
# Epoch 14/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5098
# Epoch 15/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4907
# Epoch 16/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4695
# Epoch 17/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4454
# Epoch 18/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4179
# Epoch 19/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3860
# Epoch 20/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3515
# [[0.32542747]]
# 2
# [4.]
# For df  18 : Test RMSE: 2.373
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var1(t)
# 1       1.00   0.380952   0.500000        0.0     0.75
# 2       0.75   0.702381   0.000000        0.0     1.00
# 3       1.00   0.750000   0.666667        0.0     0.75
# 4       0.75   0.892857   0.166667        0.0     0.75
# 5       0.75   0.250000   0.833333        0.0     0.00
# Epoch 1/20
# 9/9 [==============================] - 3s 3ms/step - loss: 0.6216
# Epoch 2/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6112
# Epoch 3/20
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6011
# Epoch 4/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5913
# Epoch 5/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5814
# Epoch 6/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5714
# Epoch 7/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5612
# Epoch 8/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5508
# Epoch 9/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5402
# Epoch 10/20
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5292
# Epoch 11/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5179
# Epoch 12/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5062
# Epoch 13/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4941
# Epoch 14/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4814
# Epoch 15/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4682
# Epoch 16/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4544
# Epoch 17/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4398
# Epoch 18/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4243
# Epoch 19/20
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4078
# Epoch 20/20
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3902
# [[0.2776354]]
# 1
# [3.]
# For df  19 : Test RMSE: 1.889
# 1.4354823365019207
# 0

# %%
model.summary()
# Out:
# Model: "sequential_105"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_190 (LSTM)             (None, 1, 5)              200
#
#  lstm_191 (LSTM)             (None, 3)                 108
#
#  dense_105 (Dense)           (None, 1)                 4
#
# =================================================================
# Total params: 312
# Trainable params: 312
# Non-trainable params: 0
# _________________________________________________________________

# %%
print (forecasted_trips)
# Out:
# [0, 0, 4, 5, 4, 3, 3, 1, 1, 1, 2, 2, 1, 1, 2, 2, 3, 1, 2, 1]

# %% [markdown]
# # Down Direction Processing

# %%
#Making separate dataframes for each separate timeslot over many days
df1=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df2=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df3=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df4=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df5=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df6=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df7=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df8=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df9=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df10=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df11=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df12=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df13=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df14=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df15=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df16=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df17=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df18=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df19=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df20=pd.DataFrame(columns=['Time Slot','Trips','Passengers','Day','isHoliday'])
df=[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20]

#Dicing only requird data from list of holidays
holiday_day = Holiday_data['Day']
holiday_month = Holiday_data['Month']

# %%
Timeslot_values= ['00:00:01-05:00:00','05:00:01-06:00:00','06:00:01-07:00:00','07:00:01-08:00:00','08:00:01-09:00:00','09:00:01-10:00:00','10:00:01-11:00:00','11:00:01-12:00:00','12:00:01-13:00:00','13:00:01-14:00:00','14:00:01-15:00:00','15:00:01-16:00:00','16:00:01-17:00:00','17:00:01-18:00:00','18:00:01-19:00:00','19:00:01-20:00:00','20:00:01-21:00:00','21:00:01-22:00:00','22:00:01-23:00:00','23:00:01-24:00:00']
Days = {'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6,'Sunday':7}

#Obtaining the day and date details for current day 
now = datetime.datetime.now()   
current_month = months[str(now.month).zfill(2)] 
current_day = now.day
isCurrDay_holiday = 0
current_dow = Days[now.strftime("%A")]           #Obtaining current day of the week
for i in range(1,24):                            #checking if there is holiday today
    if(holiday_day[i]==current_day and current_month==holiday_month[i]):
        isCurrDay_holiday=1

for files in down_allfiles:
    #Obtaining Day and date details from filename
    base = os.path.basename(files)
    day = os.path.splitext(base)[0][27:]
    date = os.path.splitext(base)[0][20:22]
    month = os.path.splitext(base)[0][23:26]
    
    #Determining whether holiday or not
    #year = os.path.splitext(base)[0][21:25]
    #Determining whether holiday or not
    holiday = 0
    for i in range(1,23):
        if(holiday_day[i]==date and months[month]==holiday_month[i]):
            holiday=1
            
    #Pre-processing data into required format
    day = Days[day]                                        #Mapping day to numeric value
    with open(files,'r') as f:
        timeslot = []
        trips = []
        passengers = []
        reader = csv.reader(f, delimiter=",")
        rows = [r for r in reader]
        for x in rows[1:]:
            timeslot.append(x[1])
            trips.append(x[2])
            if(x[3]==''):
                x[3]=0
            passengers.append(x[3])
 
    #Adding data into the dataframes created previously according to time slots
    for j in range(len(timeslot)):
        df[j]= df[j].append(pd.Series([timeslot[j],trips[j],int(passengers[j]),day,holiday], index = ['Time Slot','Trips','Passengers','Day','isHoliday']), ignore_index=True)
        df[j]=df[j].replace('',0)                      #Replacing NAN values by 0
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Python310\lib\linecache.py:72, in checkcache(filename)
#      71 try:
# ---> 72     stat = os.stat(fullname)
#      73 except OSError:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\Admin\\AppData\\Local\\Temp\\ipykernel_6344\\2902633725.py'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [73], in <cell line: 14>()
#      44 #Adding data into the dataframes created previously according to time slots
#      45 for j in range(len(timeslot)):
# ---> 46     df[j]= df[j].append(pd.Series([timeslot[j],trips[j],int(passengers[j]),day,holiday], index = ['Time Slot','Trips','Passengers','Day','isHoliday']), ignore_index=True)
#      47     df[j]=df[j].replace('',0)
#
# File c:\Python310\lib\site-packages\pandas\core\frame.py:9030, in DataFrame.append(self, other, ignore_index, verify_integrity, sort)
#    8923 def append(
#    8924     self,
#    8925     other,
#    (...)
#    8928     sort: bool = False,
#    8929 ) -> DataFrame:
#    8930     """
#    8931     Append rows of `other` to the end of caller, returning a new object.
#    8932
#    (...)
#    9023     4  4
#    9024     """
#    9025     warnings.warn(
#    9026         "The frame.append method is deprecated "
#    9027         "and will be removed from pandas in a future version. "
#    9028         "Use pandas.concat instead.",
#    9029         FutureWarning,
# -> 9030         stacklevel=find_stack_level(),
#    9031     )
#    9033     return self._append(other, ignore_index, verify_integrity, sort)
#
# File c:\Python310\lib\site-packages\pandas\util\_exceptions.py:32, in find_stack_level()
#      27 def find_stack_level() -> int:
#      28     """
#      29     Find the first place in the stack that is not inside pandas
#      30     (tests notwithstanding).
#      31     """
# ---> 32     stack = inspect.stack()
#      34     import pandas as pd
#      36     pkg_dir = os.path.dirname(pd.__file__)
#
# File c:\Python310\lib\inspect.py:1678, in stack(context)
#    1676 def stack(context=1):
#    1677     """Return a list of records for the stack above the caller's frame."""
# -> 1678     return getouterframes(sys._getframe(1), context)
#
# File c:\Python310\lib\inspect.py:1655, in getouterframes(frame, context)
#    1653 framelist = []
#    1654 while frame:
# -> 1655     frameinfo = (frame,) + getframeinfo(frame, context)
#    1656     framelist.append(FrameInfo(*frameinfo))
#    1657     frame = frame.f_back
#
# File c:\Python310\lib\inspect.py:1629, in getframeinfo(frame, context)
#    1627 start = lineno - 1 - context//2
#    1628 try:
# -> 1629     lines, lnum = findsource(frame)
#    1630 except OSError:
#    1631     lines = index = None
#
# File c:\Python310\lib\inspect.py:943, in findsource(object)
#     940 file = getsourcefile(object)
#     941 if file:
#     942     # Invalidate cache if needed.
# --> 943     linecache.checkcache(file)
#     944 else:
#     945     file = getfile(object)
#
# File c:\Python310\lib\site-packages\IPython\core\compilerop.py:193, in check_linecache_ipython(*args)
#     190 """Call linecache.checkcache() safely protecting our cached values.
#     191 """
#     192 # First call the original checkcache as intended
# --> 193 linecache._checkcache_ori(*args)
#     194 # Then, update back the cache with our data, so that tracebacks related
#     195 # to our compiled codes can be produced.
#     196 linecache.cache.update(linecache._ipython_cache)
#
# File c:\Python310\lib\linecache.py:72, in checkcache(filename)
#      70     continue   # no-op for files loaded via a __loader__
#      71 try:
# ---> 72     stat = os.stat(fullname)
#      73 except OSError:
#      74     cache.pop(filename, None)
#
# KeyboardInterrupt:

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg


rmse_total = 0
rmse_total_train = 0
forecasted_down_trips =[]
# load dataset
for i in range(0,20):    
    dataset = df[i].copy()
    dataset.drop('Time Slot',axis=1,inplace=True)
    values = dataset.values
    # ensure all data is float
    values = values.astype('float32')
    # normalize features
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(values)
    # frame as supervised learning
    reframed = series_to_supervised(scaled, 1, 1)
    # drop columns we don't want to predict
    reframed.drop(reframed.columns[[5,6,7]], axis=1, inplace=True)
    #print(reframed.head())             #To debug
    
    #Divide Data into Training and test set
    values = reframed.values
    #n_train_steps = 30                  #Training set size
    train_set = values[:, :]
    test_set = values[:, :]
    # split into input and outputs
    train_X, train_y = train_set[:-1,:-1], train_set[:-1,-1]
    test_X, test_y = test_set[-1:,:-1], test_set[-1:,-1]
    
    # reshape input to be 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
    test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
    
    # design network
    model = Sequential()
    model.add(LSTM(5, input_shape=(train_X.shape[1], train_X.shape[2])))    #Adding LSTM units into the RNN
    model.add(Dense(1))
    model.compile(loss='mae', optimizer='adam')                             #mae-Mean Absolute error, Adam optimization rule
    # fit network
    history = model.fit(train_X, train_y, epochs=20, batch_size=3, validation_data=(test_X, test_y), verbose=1, shuffle=False)
    
    #obtaining predictions
    test_prediction = model.predict(test_X)
    train_prediction = model.predict(train_X)
    test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
    train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))

    # invert scaling for forecast
    print (test_prediction)
    actual_prediction = concatenate((test_prediction, test_X[:, 1:]), axis=1)
    actual_prediction = scaler.inverse_transform(actual_prediction)
    actual_prediction = actual_prediction[:,0]
    for x in actual_prediction:
        print (round(x))
        if round(x)<=0:
            forecasted_down_trips.append(0)
        else:
            forecasted_down_trips.append(round(x))
    actual_train_prediction = concatenate((train_prediction, train_X[:, 1:]), axis=1)
    actual_train_prediction = scaler.inverse_transform(actual_train_prediction)
    actual_train_prediction = actual_train_prediction[:,0]
    
    #invert scaling for actual ie. already available predictions(teacher signal)
    test_y = test_y.reshape((len(test_y), 1))
    inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
    inv_y = scaler.inverse_transform(inv_y)
    inv_y = inv_y[:,0]
    print(inv_y)
    #print df[i]['Trips']
    
     #invert scaling for actual ie. already available predictions(teacher signal) for training set
    train_y = train_y.reshape((len(train_y),1))
    inv_y_train = concatenate((train_y, train_X[:, 1:]), axis=1)
    inv_y_train = scaler.inverse_transform(inv_y_train)
    inv_y_train = inv_y_train[:,0]
    
    # calculate RMSE
    rmse = sqrt(mean_squared_error(inv_y,actual_prediction))
    rmse_total += float(rmse)
    print ("For df ",i,":", ('Test RMSE: %.3f' % rmse))
    
    rmse_train = sqrt(mean_squared_error(inv_y_train, actual_train_prediction))
    rmse_total_train += float(rmse_train)
    #print "For df ",i,":", ('Train RMSE: %.3f' % rmse_train)
print(rmse_total/20.0) #, rmse_total_train/20.0

# %%
print (forecasted_trips)
print (forecasted_down_trips)
print (len(forecasted_trips))
print (len(forecasted_down_trips))
#forecasted_trips=[]
up_pass=[]                   # Removing irrelevant internal processing data
#forecasted_down_trips=[]
down_pass=[]                 # Removing irrelevant internal processing data

# %%
print (len(timeslot))
print (len(forecasted_down_trips))
print (len(forecasted_trips))

# %%
#Saving Results into CSV files 
forecast = pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
save_path=r"C:\Users\Admin\Documents\Public-Transport-System-Optimization\Dynamic Timetable Generation\Results\Forecasted Trips\\"
for j in range(len(timeslot)):
    forecast= forecast.append(pd.Series([timeslot[j],forecasted_trips[j],forecasted_down_trips[j]], index = ['Time Slot','Up_Trips','Down_Trips']), ignore_index=True)
filename ='LSTM_Forecasted_trips_'+bus_no+'_'+str(now.month).zfill(2) +'_'+str(now.day)+'_'+str(day)
forecast.to_csv(save_path + filename +'.csv')
