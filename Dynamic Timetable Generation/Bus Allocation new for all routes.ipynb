# %%
#Import files module
import pandas as pd
import csv
import re                     ##Regular expressions
import glob
import os
import logging
import numpy as np
import datetime

import warnings
warnings.filterwarnings('ignore')

# %%
#logging mechanism for debugging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
#Mapping months to numeric values
months = {'01':'Jan','02':'Feb','03':'Mar','04':'Apr','05':'May','06':'June','07':'July','08':'Aug','09':'Sept','10':'Oct','11':'Nov','12':'Dec'}

# %%
#Importing files from specific folders and list of holidays
path = r'C:\Users\Admin\Documents\Public-Transport-System-Optimization\Dynamic Timetable Generation\Results\Forecasted Trips'        # Path to folder containing all forecasted trips - change this path accordingly
allfiles = glob.glob(path + "/*.csv")
save_path=r'C:\Users\Admin\Documents\Public-Transport-System-Optimization\Dynamic Timetable Generation\Results\Schedule'             # Save path for results file
Holiday_colnames = ['Holiday', 'Date', 'Day', 'Month']
Holiday_data = pd.read_csv(r'C:\Users\Admin\Documents\Public-Transport-System-Optimization\Dynamic Timetable Generation\List of Holidays.csv', names=Holiday_colnames)
feature_names =  ['Time Slot','Trips','Passengers','Day','isHoliday']

# %%
#Making separate dataframes for each separate timeslot over many days
df1=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df2=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df3=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df4=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df5=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df6=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df7=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df8=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df9=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df10=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df11=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df12=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df13=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df14=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df15=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df16=pd.DataFrame(columns=['Time Slot','Up_Trips','Down_Trips'])
df=[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16]


#Dicing only requird data from list of holidays
holiday_day = Holiday_data['Day']
holiday_month = Holiday_data['Month']

# %%
allfiles
# Out:
# ['C:\\Users\\Admin\\Documents\\Public-Transport-System-Optimization\\Dynamic Timetable Generation\\Results\\Forecasted Trips\\Forecasted_trips_6080_06_26_3_LSTM.csv']

# %%
Timeslot_values=['00:00:01-05:00:00','05:00:01-06:00:00','06:00:01-07:00:00','07:00:01-08:00:00','08:00:01-09:00:00','09:00:01-10:00:00','10:00:01-11:00:00','11:00:01-12:00:00','12:00:01-13:00:00','13:00:01-14:00:00','14:00:01-15:00:00','15:00:01-16:00:00','16:00:01-17:00:00','17:00:01-18:00:00','18:00:01-19:00:00','19:00:01-20:00:00','20:00:01-21:00:00','21:00:01-22:00:00','22:00:01-23:00:00','23:00:01-24:00:00']
Days = {'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6,'Sunday':7}

route_info = []
file_number=0
len_files = min(16,len(allfiles))
for files in range(0,len_files):
    
    
    
    #Obtaining Day and date details from filename
    base = os.path.basename(allfiles[files])
    i = 0
    for x in range(len(base)):
        print(base[x],i)
        i = i + 1
    
    info = os.path.splitext(base)[0][17:]
    route_info.append(info)
    

            
    #Pre-processing data into required format
    with open(allfiles[files],'r') as f:
        reader = csv.reader(f, delimiter=",")
        rows = [r for r in reader]
        for x in rows[1:]:
            print(x,len(x))
            df[file_number]= df[file_number].append(pd.Series([x[1],x[2],x[3]], index = ['Time Slot','Up_Trips','Down_Trips',]), ignore_index=True)    
            df[file_number].replace('',0)
            print(df[file_number][['Up_Trips','Down_Trips',]])
            df[file_number][['Up_Trips','Down_Trips']] = df[file_number][['Up_Trips','Down_Trips']].apply(pd.to_numeric)
    file_number+=1
# Out:
# F 0
# o 1
# r 2
# e 3
# c 4
# a 5
# s 6
# t 7
# e 8
# d 9
# _ 10
# t 11
# r 12
# i 13
# p 14
# s 15
# _ 16
# 6 17
# 0 18
# 8 19
# 0 20
# _ 21
# 0 22
# 6 23
# _ 24
# 2 25
# 6 26
# _ 27
# 3 28
# _ 29
# L 30
# S 31
# T 32
# M 33
# . 34
# c 35
# s 36
# v 37
# ['0', '00:00:01-05:00:00', '0', '0'] 4
#   Up_Trips Down_Trips
# 0        0          0
# ['1', '05:00:01-06:00:00', '0', '1'] 4
#   Up_Trips Down_Trips
# 0        0          0
# 1        0          1
# ['2', '06:00:01-07:00:00', '3', '6'] 4
#   Up_Trips Down_Trips
# 0        0          0
# 1        0          1
# 2        3          6
# ['3', '07:00:01-08:00:00', '4', '5'] 4
#   Up_Trips Down_Trips
# 0        0          0
# 1        0          1
# 2        3          6
# 3        4          5
# ['4', '08:00:01-09:00:00', '4', '5'] 4
#   Up_Trips Down_Trips
# 0        0          0
# 1        0          1
# 2        3          6
# 3        4          5
# 4        4          5
# ['5', '09:00:01-10:00:00', '3', '4'] 4
#   Up_Trips Down_Trips
# 0        0          0
# 1        0          1
# 2        3          6
# 3        4          5
# 4        4          5
# 5        3          4
# ['6', '10:00:01-11:00:00', '1', '3'] 4
#   Up_Trips Down_Trips
# 0        0          0
# 1        0          1
# 2        3          6
# 3        4          5
# 4        4          5
# 5        3          4
# 6        1          3
# ['7', '11:00:01-12:00:00', '1', '3'] 4
#   Up_Trips Down_Trips
# 0        0          0
# 1        0          1
# 2        3          6
# 3        4          5
# 4        4          5
# 5        3          4
# 6        1          3
# 7        1          3
# ['8', '12:00:01-13:00:00', '2', '3'] 4
#   Up_Trips Down_Trips
# 0        0          0
# 1        0          1
# 2        3          6
# 3        4          5
# 4        4          5
# 5        3          4
# 6        1          3
# 7        1          3
# 8        2          3
# ['9', '13:00:01-14:00:00', '2', '3'] 4
#   Up_Trips Down_Trips
# 0        0          0
# 1        0          1
# 2        3          6
# 3        4          5
# 4        4          5
# 5        3          4
# 6        1          3
# 7        1          3
# 8        2          3
# 9        2          3
# ['10', '14:00:01-15:00:00', '1', '2'] 4
#    Up_Trips Down_Trips
# 0         0          0
# 1         0          1
# 2         3          6
# 3         4          5
# 4         4          5
# 5         3          4
# 6         1          3
# 7         1          3
# 8         2          3
# 9         2          3
# 10        1          2
# ['11', '15:00:01-16:00:00', '2', '2'] 4
#    Up_Trips Down_Trips
# 0         0          0
# 1         0          1
# 2         3          6
# 3         4          5
# 4         4          5
# 5         3          4
# 6         1          3
# 7         1          3
# 8         2          3
# 9         2          3
# 10        1          2
# 11        2          2
# ['12', '16:00:01-17:00:00', '2', '3'] 4
#    Up_Trips Down_Trips
# 0         0          0
# 1         0          1
# 2         3          6
# 3         4          5
# 4         4          5
# 5         3          4
# 6         1          3
# 7         1          3
# 8         2          3
# 9         2          3
# 10        1          2
# 11        2          2
# 12        2          3
# ['13', '17:00:01-18:00:00', '3', '3'] 4
#    Up_Trips Down_Trips
# 0         0          0
# 1         0          1
# 2         3          6
# 3         4          5
# 4         4          5
# 5         3          4
# 6         1          3
# 7         1          3
# 8         2          3
# 9         2          3
# 10        1          2
# 11        2          2
# 12        2          3
# 13        3          3
# ['14', '18:00:01-19:00:00', '1', '2'] 4
#    Up_Trips Down_Trips
# 0         0          0
# 1         0          1
# 2         3          6
# 3         4          5
# 4         4          5
# 5         3          4
# 6         1          3
# 7         1          3
# 8         2          3
# 9         2          3
# 10        1          2
# 11        2          2
# 12        2          3
# 13        3          3
# 14        1          2
# ['15', '19:00:01-20:00:00', '2', '3'] 4
#    Up_Trips Down_Trips
# 0         0          0
# 1         0          1
# 2         3          6
# 3         4          5
# 4         4          5
# 5         3          4
# 6         1          3
# 7         1          3
# 8         2          3
# 9         2          3
# 10        1          2
# 11        2          2
# 12        2          3
# 13        3          3
# 14        1          2
# 15        2          3
# ['16', '20:00:01-21:00:00', '2', '3'] 4
#    Up_Trips Down_Trips
# 0         0          0
# 1         0          1
# 2         3          6
# 3         4          5
# 4         4          5
# 5         3          4
# 6         1          3
# 7         1          3
# 8         2          3
# 9         2          3
# 10        1          2
# 11        2          2
# 12        2          3
# 13        3          3
# 14        1          2
# 15        2          3
# 16        2          3
# ['17', '21:00:01-22:00:00', '3', '3'] 4
#    Up_Trips Down_Trips
# 0         0          0
# 1         0          1
# 2         3          6
# 3         4          5
# 4         4          5
# 5         3          4
# 6         1          3
# 7         1          3
# 8         2          3
# 9         2          3
# 10        1          2
# 11        2          2
# 12        2          3
# 13        3          3
# 14        1          2
# 15        2          3
# 16        2          3
# 17        3          3
# ['18', '22:00:01-23:00:00', '1', '2'] 4
#    Up_Trips Down_Trips
# 0         0          0
# 1         0          1
# 2         3          6
# 3         4          5
# 4         4          5
# 5         3          4
# 6         1          3
# 7         1          3
# 8         2          3
# 9         2          3
# 10        1          2
# 11        2          2
# 12        2          3
# 13        3          3
# 14        1          2
# 15        2          3
# 16        2          3
# 17        3          3
# 18        1          2
# ['19', '23:00:01-24:00:00', '1', '2'] 4
#    Up_Trips Down_Trips
# 0         0          0
# 1         0          1
# 2         3          6
# 3         4          5
# 4         4          5
# 5         3          4
# 6         1          3
# 7         1          3
# 8         2          3
# 9         2          3
# 10        1          2
# 11        2          2
# 12        2          3
# 13        3          3
# 14        1          2
# 15        2          3
# 16        2          3
# 17        3          3
# 18        1          2
# 19        1          2

# %%
def gen_time(hours,minutes,trip_time):
    if(minutes+trip_time>=60):
        minutes=minutes+trip_time-60
        hours+=1
    else:
        minutes=minutes+trip_time
    if(hours>=24):
        hours=0
    return [hours,minutes]

def gen_hourly_schedule(start_hour,end_hour,num_trips):
    step=round((end_hour-start_hour)*60/(num_trips))
    schedule=[]
    minutes=0
    for i in range(int(num_trips)):
        schedule.append([start_hour,minutes])
        minutes+=step
    return schedule

# %%
df[0]
# Out:
#             Time Slot  Up_Trips  Down_Trips
# 0   00:00:01-05:00:00         0           0
# 1   05:00:01-06:00:00         0           1
# 2   06:00:01-07:00:00         3           6
# 3   07:00:01-08:00:00         4           5
# 4   08:00:01-09:00:00         4           5
# 5   09:00:01-10:00:00         3           4
# 6   10:00:01-11:00:00         1           3
# 7   11:00:01-12:00:00         1           3
# 8   12:00:01-13:00:00         2           3
# 9   13:00:01-14:00:00         2           3
# 10  14:00:01-15:00:00         1           2
# 11  15:00:01-16:00:00         2           2
# 12  16:00:01-17:00:00         2           3
# 13  17:00:01-18:00:00         3           3
# 14  18:00:01-19:00:00         1           2
# 15  19:00:01-20:00:00         2           3
# 16  20:00:01-21:00:00         2           3
# 17  21:00:01-22:00:00         3           3
# 18  22:00:01-23:00:00         1           2
# 19  23:00:01-24:00:00         1           2

# %%
i=0
trip_time = 0  #Set the trip time for each route - change value accordingly
df_len = len(df)
for index in range(0,1):
    if(i==0):
        trip_time=30              # For route 1
    if(i==1):
        trip_time=72              # For route 2
    if(i==2):
        trip_time=93              # For route 3
    if(i==3):
        trip_time=55              # For route 4
    if(i==4):
        trip_time=41              # For route 5
    up_trips=[]
    down_trips=[]
    #trip_time=55
    up_count = 0
    down_count = 0
    df[index].fillna(0,inplace=True)
    #for all 20 timeslots
    for i in range(0,20):
        up_trips.append(df[index]['Up_Trips'][i])
        down_trips.append(df[index]['Down_Trips'][i])
        up_count+=df[index]['Up_Trips'][i]
        down_count+=df[index]['Down_Trips'][i]
    
    #print ("up and down trips",up_trips, down_trips)
    up_bus=np.zeros(20)
    down_bus=np.zeros(20)

    up_schedule=pd.DataFrame(columns=['Hour','Minutes','Bus Tag'])
    down_schedule=pd.DataFrame(columns=['Hour','Minutes','Bus Tag'])

    up_arrival=pd.DataFrame(columns=['Hour','Minutes','Bus Tag'])
    down_arrival=pd.DataFrame(columns=['Hour','Minutes','Bus Tag'])

    curr_hour=4
    next_hour=5
    curr_min=0
    Bus_tag=0

    up_bus[0]+=1
    schedule=gen_hourly_schedule(curr_hour,next_hour,1)
    for i in range(len(schedule)):
        Bus_tag+=1
        up_schedule=up_schedule.append(pd.Series([schedule[i][0],schedule[i][1],Bus_tag],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
        arrival_time=gen_time(curr_hour,schedule[i][1],trip_time)
        #print arrival_time
        curr_min=schedule[i][1]
        down_arrival=down_arrival.append(pd.Series([arrival_time[0],arrival_time[1],Bus_tag],index=['Hour','Minutes','Bus Tag']),ignore_index=True)

    down_bus[0]+=1
    schedule=gen_hourly_schedule(curr_hour,next_hour,1)
    #print("Up schedule generated")
    #print(up_schedule,down_arrival,sep='\n',end='\n')
    for i in range(len(schedule)):
        Bus_tag+=1
        down_schedule=down_schedule.append(pd.Series([schedule[i][0],schedule[i][1],Bus_tag],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
        #print down_schedule
        arrival_time=gen_time(curr_hour,schedule[i][1],trip_time)
        #print arrival_time
        curr_min=max(schedule[i][1],curr_min)
        up_arrival=up_arrival.append(pd.Series([arrival_time[0],arrival_time[1],Bus_tag],index=['Hour','Minutes','Bus Tag']),ignore_index=True)

    up_trips[0]-=1        
    down_trips[0]-=1
    #print(down_schedule,down_arrival,sep='\n',end='\n')
    #print(up_trips,down_trips)

    for l in range(len(up_trips)):
        if(up_trips[l]>1):
            schedule=gen_hourly_schedule(curr_hour,next_hour,up_trips[l])
            for i in range(len(schedule)):
                up_schedule=up_schedule.append(pd.Series([schedule[i][0],schedule[i][1],0],index=['Hour','Minutes','Bus Tag']),ignore_index=True)

        elif(up_trips[l]==1):
             up_schedule=up_schedule.append(pd.Series([curr_hour,30,0],index=['Hour','Minutes','Bus Tag']),ignore_index=True)

        if(down_trips[l]>1):
            schedule=gen_hourly_schedule(curr_hour,next_hour,down_trips[l])
            for i in range(len(schedule)):
                down_schedule=down_schedule.append(pd.Series([schedule[i][0],schedule[i][1],0],index=['Hour','Minutes','Bus Tag']),ignore_index=True)

        elif(down_trips[l]==1):
             down_schedule=down_schedule.append(pd.Series([curr_hour,30,0],index=['Hour','Minutes','Bus Tag']),ignore_index=True)

        curr_hour+=1
        curr_min=0
        next_hour+=1

    up_count-=1
    down_count-=1
    print("schedules : ",up_schedule,down_schedule,sep='\n',end='\n')

    combined=pd.DataFrame(columns=['Dir','Hour','Minutes','Bus Tag'])
    for i in range(1,len(up_schedule)):
        combined=combined.append(pd.Series(['U',up_schedule['Hour'].iloc[i],up_schedule['Minutes'].iloc[i],up_schedule['Bus Tag'].iloc[i]],index=['Dir','Hour','Minutes','Bus Tag']),ignore_index=True)

    for i in range(1,len(down_schedule)):
        combined=combined.append(pd.Series(['D',down_schedule['Hour'].iloc[i],down_schedule['Minutes'].iloc[i],down_schedule['Bus Tag'].iloc[i]],index=['Dir','Hour','Minutes','Bus Tag']),ignore_index=True)

    combined.sort_values(['Hour','Minutes','Dir'], ascending=[True, True, False],inplace=True)
    print(combined)
    
    up_schedule_index=1
    down_schedule_index=1
    for i in range(len(combined)):
        if(combined['Dir'].iloc[i]=='U'): #an up direction bus
            down_count-=1 #as this bus will return 
            if(down_count>0): #more buses to return
                if(len(up_arrival)>0): #buses are arriving at up
                    up_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True) #
                    if(up_arrival['Hour'].iloc[0]<combined['Hour'].iloc[i] or (up_arrival['Hour'].iloc[0]==combined['Hour'].iloc[i] and up_arrival['Minutes'].iloc[0]<=combined['Minutes'].iloc[i])):
                        #print up_arrival.loc[up_arrival.index[[0]], :]
                        rows = up_arrival.loc[up_arrival.index[[0]], :]
                        if(rows['Hour'].iloc[0]<combined['Hour'].iloc[i]):
                        #print i, curr_hour
                            combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                            up_schedule['Bus Tag'].iloc[up_schedule_index]=rows['Bus Tag'].iloc[0]
                            rows['Hour'].iloc[0]=combined['Hour'].iloc[i]
                            rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                        elif(rows['Hour'].iloc[0]==combined['Hour'].iloc[i] and rows['Minutes'].iloc[0]<=combined['Minutes'].iloc[i]):
                            combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                            up_schedule['Bus Tag'].iloc[up_schedule_index]=rows['Bus Tag'].iloc[0] 
                            rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                        arrival_time=gen_time(rows['Hour'].iloc[0],rows['Minutes'].iloc[0],trip_time)
                        down_arrival= down_arrival.append(pd.Series([arrival_time[0],arrival_time[1],rows['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        up_arrival.drop(up_arrival.index[[0]], inplace=True)
                        up_schedule_index+=1
                    else:
                        if(len(down_arrival)>0):
                            down_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                            arrival_time=gen_time(down_arrival['Hour'].iloc[0],down_arrival['Minutes'].iloc[0],trip_time)
                            if(arrival_time[0]<combined['Hour'].iloc[i]) or (arrival_time[0]==combined['Hour'].iloc[i] and arrival_time[1]<combined['Minutes'].iloc[i]):
                                up_arrival= up_arrival.append(pd.Series([arrival_time[0],arrival_time[1],down_arrival['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                                down_arrival.drop(down_arrival.index[[0]], inplace=True)
                                up_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                                rows = up_arrival.loc[up_arrival.index[[0]], :]
                                if(rows['Hour'].iloc[0]<combined['Hour'].iloc[i]):
                                    #print i, curr_hour
                                    combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                                    up_schedule['Bus Tag'].iloc[up_schedule_index]=rows['Bus Tag'].iloc[0]
                                    rows['Hour'].iloc[0]=combined['Hour'].iloc[i]
                                    rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                                elif(rows['Hour'].iloc[0]==combined['Hour'].iloc[i] and rows['Minutes'].iloc[0]<=combined['Minutes'].iloc[i]):
                                    combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                                    up_schedule['Bus Tag'].iloc[up_schedule_index]=rows['Bus Tag'].iloc[0] 
                                    rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                                arrival_time=gen_time(rows['Hour'].iloc[0],rows['Minutes'].iloc[0],trip_time)
                                down_arrival= down_arrival.append(pd.Series([arrival_time[0],arrival_time[1],rows['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                                up_arrival.drop(up_arrival.index[[0]], inplace=True)
                                up_schedule_index+=1
                            else:
                                #New BUS
                                Bus_tag+=1
                                #up_bus[i]+=1
                                arrival_time=gen_time(combined['Hour'].iloc[i],combined['Minutes'].iloc[i],trip_time)
                                combined['Bus Tag'].iloc[i]=Bus_tag
                                up_schedule['Bus Tag'].iloc[up_schedule_index]=Bus_tag 
                                down_arrival=down_arrival.append(pd.Series([arrival_time[0],arrival_time[1],Bus_tag],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                                up_schedule_index+=1
                        else:
                            #New BUS
                            Bus_tag+=1
                            #up_bus[i]+=1
                            arrival_time=gen_time(combined['Hour'].iloc[i],combined['Minutes'].iloc[i],trip_time)
                            combined['Bus Tag'].iloc[i]=Bus_tag
                            up_schedule['Bus Tag'].iloc[up_schedule_index]=Bus_tag 
                            down_arrival=down_arrival.append(pd.Series([arrival_time[0],arrival_time[1],Bus_tag],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                            up_schedule_index+=1
                else:#for len(up_arrival)<=0
                    down_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                    arrival_time=gen_time(down_arrival['Hour'].iloc[0],down_arrival['Minutes'].iloc[0],trip_time)
                    if(arrival_time[0]<combined['Hour'].iloc[i]) or (arrival_time[0]==combined['Hour'].iloc[i] and arrival_time[1]<combined['Minutes'].iloc[i]):
                        up_arrival= up_arrival.append(pd.Series([arrival_time[0],arrival_time[1],down_arrival['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        down_arrival.drop(down_arrival.index[[0]], inplace=True)
                        up_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                        rows = up_arrival.loc[up_arrival.index[[0]], :]
                        if(rows['Hour'].iloc[0]<combined['Hour'].iloc[i]):
                        #print i, curr_hour
                            combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                            up_schedule['Bus Tag'].iloc[up_schedule_index]=rows['Bus Tag'].iloc[0]
                            rows['Hour'].iloc[0]=combined['Hour'].iloc[i]
                            rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                        elif(rows['Hour'].iloc[0]==combined['Hour'].iloc[i] and rows['Minutes'].iloc[0]<=combined['Minutes'].iloc[i]):
                            combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                            up_schedule['Bus Tag'].iloc[up_schedule_index]=rows['Bus Tag'].iloc[0] 
                            rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                        arrival_time=gen_time(rows['Hour'].iloc[0],rows['Minutes'].iloc[0],trip_time)
                        down_arrival= down_arrival.append(pd.Series([arrival_time[0],arrival_time[1],rows['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        up_arrival.drop(up_arrival.index[[0]], inplace=True)
                        up_schedule_index+=1

                    else:#New BUS
                        Bus_tag+=1
                        #up_bus[i]+=1
                        arrival_time=gen_time(combined['Hour'].iloc[i],combined['Minutes'].iloc[i],trip_time)
                        combined['Bus Tag'].iloc[i]=Bus_tag
                        up_schedule['Bus Tag'].iloc[up_schedule_index]=Bus_tag 
                        down_arrival=down_arrival.append(pd.Series([arrival_time[0],arrival_time[1],Bus_tag],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        up_schedule_index+=1

            else:#for down_count <=0
                    down_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                    arrival_time=gen_time(down_arrival['Hour'].iloc[0],down_arrival['Minutes'].iloc[0],trip_time)
                    if(arrival_time[0]<combined['Hour'].iloc[i]) or (arrival_time[0]==combined['Hour'].iloc[i] and arrival_time[1]<combined['Minutes'].iloc[i]):
                        up_arrival= up_arrival.append(pd.Series([arrival_time[0],arrival_time[1],down_arrival['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        down_arrival.drop(down_arrival.index[[0]], inplace=True)
                        up_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                        rows = up_arrival.loc[up_arrival.index[[0]], :]
                        if(rows['Hour'].iloc[0]<combined['Hour'].iloc[i]):
                        #print i, curr_hour
                            combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                            up_schedule['Bus Tag'].iloc[up_schedule_index]=rows['Bus Tag'].iloc[0]
                            rows['Hour'].iloc[0]=combined['Hour'].iloc[i]
                            rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                        elif(rows['Hour'].iloc[0]==combined['Hour'].iloc[i] and rows['Minutes'].iloc[0]<=combined['Minutes'].iloc[i]):
                            combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                            up_schedule['Bus Tag'].iloc[up_schedule_index]=rows['Bus Tag'].iloc[0] 
                            rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                        arrival_time=gen_time(rows['Hour'].iloc[0],rows['Minutes'].iloc[0],trip_time)
                        down_arrival= down_arrival.append(pd.Series([arrival_time[0],arrival_time[1],rows['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        up_arrival.drop(up_arrival.index[[0]], inplace=True)
                        up_schedule_index+=1

                    else:#New BUS
                        Bus_tag+=1
                        #up_bus[i]+=1
                        arrival_time=gen_time(combined['Hour'].iloc[i],combined['Minutes'].iloc[i],trip_time)
                        combined['Bus Tag'].iloc[i]=Bus_tag
                        up_schedule['Bus Tag'].iloc[up_schedule_index]=Bus_tag 
                        down_arrival=down_arrival.append(pd.Series([arrival_time[0],arrival_time[1],Bus_tag],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        up_schedule_index+=1
        else:
            up_count-=1
            if(up_count>0):
                if(len(down_arrival)>0):
                    down_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                    if(down_arrival['Hour'].iloc[0]<combined['Hour'].iloc[i] or (down_arrival['Hour'].iloc[0]==combined['Hour'].iloc[i] and down_arrival['Minutes'].iloc[0]<=combined['Minutes'].iloc[i])):
                        #print up_arrival.loc[up_arrival.index[[0]], :]
                        rows = down_arrival.loc[down_arrival.index[[0]], :]
                        if(rows['Hour'].iloc[0]<combined['Hour'].iloc[i]):
                        #print i, curr_hour
                            combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                            down_schedule['Bus Tag'].iloc[down_schedule_index]=rows['Bus Tag'].iloc[0]
                            rows['Hour'].iloc[0]=combined['Hour'].iloc[i]
                            rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                        elif(rows['Hour'].iloc[0]==combined['Hour'].iloc[i] and rows['Minutes'].iloc[0]<=combined['Minutes'].iloc[i]):
                            combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                            down_schedule['Bus Tag'].iloc[down_schedule_index]=rows['Bus Tag'].iloc[0] 
                            rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                        arrival_time=gen_time(rows['Hour'].iloc[0],rows['Minutes'].iloc[0],trip_time)
                        up_arrival= up_arrival.append(pd.Series([arrival_time[0],arrival_time[1],rows['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        down_arrival.drop(down_arrival.index[[0]], inplace=True)
                        down_schedule_index+=1
                    else:
                        if(len(up_arrival)>0):
                            up_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                            arrival_time=gen_time(up_arrival['Hour'].iloc[0],up_arrival['Minutes'].iloc[0],trip_time)
                            if(arrival_time[0]<combined['Hour'].iloc[i]) or (arrival_time[0]==combined['Hour'].iloc[i] and arrival_time[1]<combined['Minutes'].iloc[i]):
                                down_arrival= down_arrival.append(pd.Series([arrival_time[0],arrival_time[1],up_arrival['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                                up_arrival.drop(up_arrival.index[[0]], inplace=True)
                                down_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                                rows = down_arrival.loc[down_arrival.index[[0]], :]
                                if(rows['Hour'].iloc[0]<combined['Hour'].iloc[i]):
                                    #print i, curr_hour
                                    combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                                    down_schedule['Bus Tag'].iloc[down_schedule_index]=rows['Bus Tag'].iloc[0]
                                    rows['Hour'].iloc[0]=combined['Hour'].iloc[i]
                                    rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                                elif(rows['Hour'].iloc[0]==combined['Hour'].iloc[i] and rows['Minutes'].iloc[0]<=combined['Minutes'].iloc[i]):
                                    combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                                    down_schedule['Bus Tag'].iloc[down_schedule_index]=rows['Bus Tag'].iloc[0] 
                                    rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                                arrival_time=gen_time(rows['Hour'].iloc[0],rows['Minutes'].iloc[0],trip_time)
                                up_arrival= up_arrival.append(pd.Series([arrival_time[0],arrival_time[1],rows['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                                down_arrival.drop(down_arrival.index[[0]], inplace=True)
                                down_schedule_index+=1
                            else:
                                #New BUS
                                Bus_tag+=1
                                #down_bus[i]+=1
                                arrival_time=gen_time(combined['Hour'].iloc[i],combined['Minutes'].iloc[i],trip_time)
                                combined['Bus Tag'].iloc[i]=Bus_tag
                                down_schedule['Bus Tag'].iloc[down_schedule_index]=Bus_tag 
                                up_arrival=up_arrival.append(pd.Series([arrival_time[0],arrival_time[1],Bus_tag],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                                down_schedule_index+=1
                        else:
                            #New BUS
                            Bus_tag+=1
                            #down_bus[i]+=1
                            arrival_time=gen_time(combined['Hour'].iloc[i],combined['Minutes'].iloc[i],trip_time)
                            combined['Bus Tag'].iloc[i]=Bus_tag
                            down_schedule['Bus Tag'].iloc[down_schedule_index]=Bus_tag 
                            up_arrival=up_arrival.append(pd.Series([arrival_time[0],arrival_time[1],Bus_tag],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                            down_schedule_index+=1
                else:#for len(down_arrival)<=0
                    up_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                    arrival_time=gen_time(up_arrival['Hour'].iloc[0],up_arrival['Minutes'].iloc[0],trip_time)
                    if(arrival_time[0]<combined['Hour'].iloc[i]) or (arrival_time[0]==combined['Hour'].iloc[i] and arrival_time[1]<combined['Minutes'].iloc[i]):
                        down_arrival= down_arrival.append(pd.Series([arrival_time[0],arrival_time[1],up_arrival['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        up_arrival.drop(up_arrival.index[[0]], inplace=True)
                        down_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                        rows = down_arrival.loc[down_arrival.index[[0]], :]
                        if(rows['Hour'].iloc[0]<combined['Hour'].iloc[i]):
                        #print i, curr_hour
                            combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                            down_schedule['Bus Tag'].iloc[down_schedule_index]=rows['Bus Tag'].iloc[0]
                            rows['Hour'].iloc[0]=combined['Hour'].iloc[i]
                            rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                        elif(rows['Hour'].iloc[0]==combined['Hour'].iloc[i] and rows['Minutes'].iloc[0]<=combined['Minutes'].iloc[i]):
                            combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                            down_schedule['Bus Tag'].iloc[down_schedule_index]=rows['Bus Tag'].iloc[0] 
                            rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                        arrival_time=gen_time(rows['Hour'].iloc[0],rows['Minutes'].iloc[0],trip_time)
                        up_arrival= up_arrival.append(pd.Series([arrival_time[0],arrival_time[1],rows['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        down_arrival.drop(down_arrival.index[[0]], inplace=True)
                        down_schedule_index+=1

                    else:#New BUS
                        Bus_tag+=1
                        #down_bus[i]+=1
                        arrival_time=gen_time(combined['Hour'].iloc[i],combined['Minutes'].iloc[i],trip_time)
                        combined['Bus Tag'].iloc[i]=Bus_tag
                        down_schedule['Bus Tag'].iloc[down_schedule_index]=Bus_tag 
                        up_arrival=up_arrival.append(pd.Series([arrival_time[0],arrival_time[1],Bus_tag],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        down_schedule_index+=1

            else:#for up_count <=0
                    up_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                    #if(i==1):
                        #print up_arrival
                        #print "outut"
                    arrival_time=gen_time(up_arrival['Hour'].iloc[0],up_arrival['Minutes'].iloc[0],trip_time)
                    if(arrival_time[0]<combined['Hour'].iloc[i]) or (arrival_time[0]==combined['Hour'].iloc[i] and arrival_time[1]<combined['Minutes'].iloc[i]):
                        down_arrival= down_arrival.append(pd.Series([arrival_time[0],arrival_time[1],up_arrival['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        up_arrival.drop(up_arrival.index[[0]], inplace=True)
                        down_arrival.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
                        rows = down_arrival.loc[down_arrival.index[[0]], :]
                        if(rows['Hour'].iloc[0]<combined['Hour'].iloc[i]):
                        #print i, curr_hour
                            combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                            down_schedule['Bus Tag'].iloc[down_schedule_index]=rows['Bus Tag'].iloc[0]
                            rows['Hour'].iloc[0]=combined['Hour'].iloc[i]
                            rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                        elif(rows['Hour'].iloc[0]==combined['Hour'].iloc[i] and rows['Minutes'].iloc[0]<=combined['Minutes'].iloc[i]):
                            combined['Bus Tag'].iloc[i]=rows['Bus Tag'].iloc[0]
                            down_schedule['Bus Tag'].iloc[down_schedule_index]=rows['Bus Tag'].iloc[0] 
                            rows['Minutes'].iloc[0]=combined['Minutes'].iloc[i]
                        arrival_time=gen_time(rows['Hour'].iloc[0],rows['Minutes'].iloc[0],trip_time)
                        up_arrival= up_arrival.append(pd.Series([arrival_time[0],arrival_time[1],rows['Bus Tag'].iloc[0]],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        down_arrival.drop(down_arrival.index[[0]], inplace=True)
                        down_schedule_index+=1

                    else:#New BUS
                        Bus_tag+=1
                        #down_bus[i]+=1
                        arrival_time=gen_time(combined['Hour'].iloc[i],combined['Minutes'].iloc[i],trip_time)
                        combined['Bus Tag'].iloc[i]=Bus_tag
                        down_schedule['Bus Tag'].iloc[down_schedule_index]=Bus_tag 
                        up_arrival=up_arrival.append(pd.Series([arrival_time[0],arrival_time[1],Bus_tag],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
                        down_schedule_index+=1
    
    total_bus = Bus_tag  
    down_schedule.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
    up_schedule.sort_values(['Hour','Minutes'], ascending=[True, True],inplace=True)
    final_row=pd.DataFrame(columns=['Hour','Minutes','Bus Tag'])
    final_row=final_row.append(pd.Series(['','Total Buses required on route:',total_bus],index=['Hour','Minutes','Bus Tag']),ignore_index=True)
    schedule_file_name = "Bus Schedule_"+route_info[index]
    frames=[up_schedule,down_schedule,final_row]
    result = pd.concat(frames, keys=['Up', 'Down', 'Summary'])
    result.to_csv(save_path + "\\" +schedule_file_name+'.csv')
    i+=1
# Out:
# schedules :
#    Hour Minutes Bus Tag
# 0     4       0       1
# 1     6       0       0
# 2     6      20       0
# 3     6      40       0
# 4     7       0       0
# 5     7      15       0
# 6     7      30       0
# 7     7      45       0
# 8     8       0       0
# 9     8      15       0
# 10    8      30       0
# 11    8      45       0
# 12    9       0       0
# 13    9      20       0
# 14    9      40       0
# 15   10      30       0
# 16   11      30       0
# 17   12       0       0
# 18   12      30       0
# 19   13       0       0
# 20   13      30       0
# 21   14      30       0
# 22   15       0       0
# 23   15      30       0
# 24   16       0       0
# 25   16      30       0
# 26   17       0       0
# 27   17      20       0
# 28   17      40       0
# 29   18      30       0
# 30   19       0       0
# 31   19      30       0
# 32   20       0       0
# 33   20      30       0
# 34   21       0       0
# 35   21      20       0
# 36   21      40       0
# 37   22      30       0
# 38   23      30       0
#    Hour Minutes Bus Tag
# 0     4       0       2
# 1     5      30       0
# 2     6       0       0
# 3     6      10       0
# 4     6      20       0
# 5     6      30       0
# 6     6      40       0
# 7     6      50       0
# 8     7       0       0
# 9     7      12       0
# 10    7      24       0
# 11    7      36       0
# 12    7      48       0
# 13    8       0       0
# 14    8      12       0
# 15    8      24       0
# 16    8      36       0
# 17    8      48       0
# 18    9       0       0
# 19    9      15       0
# 20    9      30       0
# 21    9      45       0
# 22   10       0       0
# 23   10      20       0
# 24   10      40       0
# 25   11       0       0
# 26   11      20       0
# 27   11      40       0
# 28   12       0       0
# 29   12      20       0
# 30   12      40       0
# 31   13       0       0
# 32   13      20       0
# 33   13      40       0
# 34   14       0       0
# 35   14      30       0
# 36   15       0       0
# 37   15      30       0
# 38   16       0       0
# 39   16      20       0
# 40   16      40       0
# 41   17       0       0
# 42   17      20       0
# 43   17      40       0
# 44   18       0       0
# 45   18      30       0
# 46   19       0       0
# 47   19      20       0
# 48   19      40       0
# 49   20       0       0
# 50   20      20       0
# 51   20      40       0
# 52   21       0       0
# 53   21      20       0
# 54   21      40       0
# 55   22       0       0
# 56   22      30       0
# 57   23       0       0
# 58   23      30       0
#    Dir Hour Minutes Bus Tag
# 38   D    5      30       0
# 0    U    6       0       0
# 39   D    6       0       0
# 40   D    6      10       0
# 1    U    6      20       0
# ..  ..  ...     ...     ...
# 36   U   22      30       0
# 93   D   22      30       0
# 94   D   23       0       0
# 37   U   23      30       0
# 95   D   23      30       0
#
# [96 rows x 4 columns]

# %%
print(result)
# Out:
#            Hour                         Minutes Bus Tag
# Up      0     4                               0       1
#         1     6                               0       2
#         2     6                              20       1
#         3     6                              40       3
#         4     7                               0       4
# ...         ...                             ...     ...
# Down    55   22                               0       4
#         56   22                              30       7
#         57   23                               0       2
#         58   23                              30      20
# Summary 0        Total Buses required on route:      20
#
# [99 rows x 3 columns]

# %%
print (combined)
# Out:
#    Dir Hour Minutes Bus Tag
# 38   D    5      30       1
# 0    U    6       0       2
# 39   D    6       0       3
# 40   D    6      10       4
# 1    U    6      20       1
# ..  ..  ...     ...     ...
# 36   U   22      30      17
# 93   D   22      30       7
# 94   D   23       0       2
# 37   U   23      30       4
# 95   D   23      30      20
#
# [96 rows x 4 columns]

# %%
print (up_schedule)
# Out:
#    Hour Minutes Bus Tag
# 0     4       0       1
# 1     6       0       2
# 2     6      20       1
# 3     6      40       3
# 4     7       0       4
# 5     7      15       5
# 6     7      30       2
# 7     7      45       6
# 8     8       0       1
# 9     8      15       3
# 10    8      30       8
# 11    8      45       4
# 12    9       0       5
# 13    9      20       2
# 14    9      40       7
# 15   10      30       1
# 16   11      30       4
# 17   12       0       6
# 18   12      30       7
# 19   13       0       3
# 20   13      30       8
# 21   14      30       5
# 22   15       0       2
# 23   15      30       6
# 24   16       0       1
# 25   16      30       4
# 26   17       0       7
# 27   17      20       3
# 28   17      40       8
# 29   18      30       9
# 30   19       0      11
# 31   19      30       5
# 32   20       0      12
# 33   20      30       1
# 34   21       0      13
# 35   21      20      14
# 36   21      40      15
# 37   22      30      17
# 38   23      30       4

# %%
print (down_schedule)
print (Bus_tag)
# Out:
#    Hour Minutes Bus Tag
# 0     4       0       2
# 1     5      30       1
# 2     6       0       3
# 3     6      10       4
# 4     6      20       5
# 5     6      30       2
# 6     6      40       6
# 7     6      50       1
# 8     7       0       7
# 9     7      12       3
# 10    7      24       8
# 11    7      36       4
# 12    7      48       5
# 13    8       0       2
# 14    8      12       7
# 15    8      24       6
# 16    8      36       1
# 17    8      48       3
# 18    9       0       8
# 19    9      15       4
# 20    9      30       5
# 21    9      45       6
# 22   10       0       2
# 23   10      20       7
# 24   10      40       3
# 25   11       0       1
# 26   11      20       8
# 27   11      40       5
# 28   12       0       4
# 29   12      20       2
# 30   12      40       6
# 31   13       0       7
# 32   13      20       1
# 33   13      40       3
# 34   14       0       8
# 35   14      30       4
# 36   15       0       5
# 37   15      30       7
# 38   16       0       3
# 39   16      20       8
# 40   16      40       2
# 41   17       0       9
# 42   17      20      10
# 43   17      40      11
# 44   18       0       6
# 45   18      30       5
# 46   19       0      12
# 47   19      20       1
# 48   19      40      13
# 49   20       0      14
# 50   20      20      15
# 51   20      40      16
# 52   21       0      17
# 53   21      20      18
# 54   21      40      19
# 55   22       0       4
# 56   22      30       7
# 57   23       0       2
# 58   23      30      20
# 20
